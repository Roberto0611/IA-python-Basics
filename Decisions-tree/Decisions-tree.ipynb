# %%
import pandas as pd 

datos = pd.read_csv('train.csv')

# %%
datos.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
datos.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import seaborn as sb 

sb.countplot(x='Survived',data=datos)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sb.countplot(x='Survived',data=datos, hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
datos.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sb.displot(x="Age",data=datos)

# %%
datos['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
datos["Age"].mean()
# Out:
# 29.69911764705882

# %%
#Llenar los datos vacios de age con un promedio
datos['Age'] = datos['Age'].fillna(datos["Age"].mean())

# %%
datos['Age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
datos.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
datos = datos.drop(["Cabin"],axis=1)

# %%
datos.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
datos["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
datos = datos.dropna()

# %%
datos.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
datos.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
#Quitar algunos datos inutiles
datos = datos.drop(["Name","PassengerId","Ticket"], axis=1)

# %%
datos.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
dummies_sex = pd.get_dummies(datos['Sex'], dtype=int, drop_first=True)

# %%
datos = datos.drop(['Sex'], axis=1)

# %%
sb.countplot(x='Survived',data=datos,hue='Embarked')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
dummies_embarked = pd.get_dummies(datos['Embarked'], dtype=int, drop_first=True)

# %%
datos = datos.join(dummies_embarked)
datos = datos.drop(["Embarked"],axis=1)

# %%
datos.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Q  S
# 0         0       3  22.0      1      0   7.2500  0  1
# 1         1       1  38.0      1      0  71.2833  0  0
# 2         1       3  26.0      0      0   7.9250  0  1
# 3         1       1  35.0      1      0  53.1000  0  1
# 4         0       3  35.0      0      0   8.0500  0  1

# %%
sb.heatmap(datos.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
sb.countplot(x='Survived', data=datos, hue='Pclass')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
x = datos.drop(["Survived"], axis=1)
y = datos["Survived"]

# %%
from sklearn.model_selection import train_test_split

x_ent, x_pru, y_ent, y_pru = train_test_split(x,y, test_size=.2)

# %%
from sklearn.tree import DecisionTreeClassifier

modelo = DecisionTreeClassifier(max_depth=50)
modelo.fit(x_ent,y_ent)
predicciones = modelo.predict(x_pru)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pru, predicciones)
# Out:
# 0.6910112359550562

# %%
from sklearn.tree import DecisionTreeClassifier

resultados = []
for i in range(1,15):
    modelo = DecisionTreeClassifier(max_depth=i)
    modelo.fit(x_ent,y_ent)
    predicciones = modelo.predict(x_pru)
    exactitud = accuracy_score(y_pru, predicciones)
    print(f"Resultado para {i}: {exactitud}")
    resultados.append(exactitud)
print(max(resultados))
# Out:
# Resultado para 1: 0.6797752808988764
# Resultado para 2: 0.6741573033707865
# Resultado para 3: 0.6966292134831461
# Resultado para 4: 0.6910112359550562
# Resultado para 5: 0.6966292134831461
# Resultado para 6: 0.6853932584269663
# Resultado para 7: 0.6629213483146067
# Resultado para 8: 0.7359550561797753
# Resultado para 9: 0.6966292134831461
# Resultado para 10: 0.6685393258426966
# Resultado para 11: 0.6797752808988764
# Resultado para 12: 0.6853932584269663
# Resultado para 13: 0.6910112359550562
# Resultado para 14: 0.6741573033707865
# 0.7359550561797753

# %%
sb.lineplot(data=resultados)
# Out:
# <Axes: >

# %%
modelo = DecisionTreeClassifier(max_depth=i)
modelo.fit(x_ent,y_ent)
predicciones = modelo.predict(x_pru)
exactitud = accuracy_score(y_pru, predicciones)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pru,predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.83      0.76       109
#            1       0.62      0.43      0.51        69
#
#     accuracy                           0.68       178
#    macro avg       0.66      0.63      0.64       178
# weighted avg       0.67      0.68      0.67       178

# %%
x_ent.columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Q', 'S'], dtype='object')

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt 

plt.figure(figsize=(10,8))
plot_tree(
    modelo,
    feature_names= x_ent.columns,
    class_names=["Murio","sobrevivio"],
    filled=True, label="none"
)
# Out:
# [Text(0.42423980005115963, 0.9666666666666667, 'Pclass <= 2.5\n0.472\n711\n[440, 271]\nMurio'),
#  Text(0.21392980474079126, 0.9, 'Fare <= 13.646\n0.495\n320\n[144, 176]\nsobrevivio'),
#  Text(0.05115961800818554, 0.8333333333333334, 'Fare <= 7.75\n0.411\n76\n[54, 22]\nMurio'),
#  Text(0.045702592087312414, 0.7666666666666667, '0.0\n10\n[10, 0]\nMurio'),
#  Text(0.056616643929058665, 0.7666666666666667, 'Age <= 26.5\n0.444\n66\n[44, 22]\nMurio'),
#  Text(0.021828103683492497, 0.7, 'Age <= 17.5\n0.255\n20\n[17, 3]\nMurio'),
#  Text(0.010914051841746248, 0.6333333333333333, 'Age <= 16.5\n0.444\n3\n[1, 2]\nsobrevivio'),
#  Text(0.005457025920873124, 0.5666666666666667, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.01637107776261937, 0.5666666666666667, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.03274215552523874, 0.6333333333333333, 'Fare <= 11.0\n0.111\n17\n[16, 1]\nMurio'),
#  Text(0.027285129604365622, 0.5666666666666667, 'Age <= 21.0\n0.375\n4\n[3, 1]\nMurio'),
#  Text(0.021828103683492497, 0.5, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.03274215552523874, 0.5, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.03819918144611187, 0.5666666666666667, '0.0\n13\n[13, 0]\nMurio'),
#  Text(0.09140518417462483, 0.7, 'Age <= 51.0\n0.485\n46\n[27, 19]\nMurio'),
#  Text(0.07366984993178717, 0.6333333333333333, 'Age <= 39.5\n0.497\n39\n[21, 18]\nMurio'),
#  Text(0.054570259208731244, 0.5666666666666667, 'Age <= 29.85\n0.475\n31\n[19, 12]\nMurio'),
#  Text(0.04365620736698499, 0.5, 'Age <= 29.35\n0.486\n12\n[5, 7]\nsobrevivio'),
#  Text(0.03819918144611187, 0.43333333333333335, 'Fare <= 13.25\n0.5\n10\n[5, 5]\nMurio'),
#  Text(0.03274215552523874, 0.36666666666666664, 'Fare <= 11.575\n0.494\n9\n[4, 5]\nsobrevivio'),
#  Text(0.021828103683492497, 0.3, 'Age <= 27.5\n0.5\n4\n[2, 2]\nMurio'),
#  Text(0.01637107776261937, 0.23333333333333334, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.027285129604365622, 0.23333333333333334, 'Age <= 28.5\n0.444\n3\n[2, 1]\nMurio'),
#  Text(0.021828103683492497, 0.16666666666666666, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.03274215552523874, 0.16666666666666666, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.04365620736698499, 0.3, 'Age <= 27.5\n0.48\n5\n[2, 3]\nsobrevivio'),
#  Text(0.03819918144611187, 0.23333333333333334, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.04911323328785812, 0.23333333333333334, 'Fare <= 12.825\n0.375\n4\n[1, 3]\nsobrevivio'),
#  Text(0.04365620736698499, 0.16666666666666666, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.054570259208731244, 0.16666666666666666, '0.444\n3\n[1, 2]\nsobrevivio'),
#  Text(0.04365620736698499, 0.36666666666666664, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.04911323328785812, 0.43333333333333335, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.06548431105047749, 0.5, 'Fare <= 12.637\n0.388\n19\n[14, 5]\nMurio'),
#  Text(0.06002728512960437, 0.43333333333333335, '0.0\n6\n[6, 0]\nMurio'),
#  Text(0.07094133697135062, 0.43333333333333335, 'Age <= 37.5\n0.473\n13\n[8, 5]\nMurio'),
#  Text(0.06548431105047749, 0.36666666666666664, 'Age <= 30.5\n0.496\n11\n[6, 5]\nMurio'),
#  Text(0.06002728512960437, 0.3, '0.375\n4\n[3, 1]\nMurio'),
#  Text(0.07094133697135062, 0.3, 'Age <= 33.25\n0.49\n7\n[3, 4]\nsobrevivio'),
#  Text(0.06548431105047749, 0.23333333333333334, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.07639836289222374, 0.23333333333333334, 'Age <= 35.0\n0.48\n5\n[3, 2]\nMurio'),
#  Text(0.07094133697135062, 0.16666666666666666, '0.444\n3\n[2, 1]\nMurio'),
#  Text(0.08185538881309687, 0.16666666666666666, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.07639836289222374, 0.36666666666666664, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.0927694406548431, 0.5666666666666667, 'Fare <= 11.75\n0.375\n8\n[2, 6]\nsobrevivio'),
#  Text(0.08731241473396999, 0.5, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.09822646657571624, 0.5, 'Age <= 47.5\n0.444\n6\n[2, 4]\nsobrevivio'),
#  Text(0.0927694406548431, 0.43333333333333335, 'Age <= 41.0\n0.32\n5\n[1, 4]\nsobrevivio'),
#  Text(0.08731241473396999, 0.36666666666666664, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.09822646657571624, 0.36666666666666664, 'Fare <= 13.25\n0.375\n4\n[1, 3]\nsobrevivio'),
#  Text(0.0927694406548431, 0.3, '0.444\n3\n[1, 2]\nsobrevivio'),
#  Text(0.10368349249658936, 0.3, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.10368349249658936, 0.43333333333333335, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.10914051841746249, 0.6333333333333333, 'Age <= 60.5\n0.245\n7\n[6, 1]\nMurio'),
#  Text(0.10368349249658936, 0.5666666666666667, '0.0\n5\n[5, 0]\nMurio'),
#  Text(0.1145975443383356, 0.5666666666666667, 'Age <= 64.0\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.10914051841746249, 0.5, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.12005457025920874, 0.5, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.376699991473397, 0.8333333333333334, 'Age <= 59.0\n0.466\n244\n[90, 154]\nsobrevivio'),
#  Text(0.2499893417462483, 0.7666666666666667, 'Age <= 17.5\n0.452\n232\n[80, 152]\nsobrevivio'),
#  Text(0.15279672578444747, 0.7, 'Fare <= 135.775\n0.147\n25\n[2, 23]\nsobrevivio'),
#  Text(0.14188267394270124, 0.6333333333333333, 'Parch <= 0.5\n0.083\n23\n[1, 22]\nsobrevivio'),
#  Text(0.1364256480218281, 0.5666666666666667, 'Fare <= 28.035\n0.32\n5\n[1, 4]\nsobrevivio'),
#  Text(0.13096862210095497, 0.5, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.14188267394270124, 0.5, '0.0\n4\n[0, 4]\nsobrevivio'),
#  Text(0.14733969986357434, 0.5666666666666667, '0.0\n18\n[0, 18]\nsobrevivio'),
#  Text(0.16371077762619374, 0.6333333333333333, 'SibSp <= 0.5\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.1582537517053206, 0.5666666666666667, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.16916780354706684, 0.5666666666666667, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.3471819577080491, 0.7, 'Fare <= 77.623\n0.47\n207\n[78, 129]\nsobrevivio'),
#  Text(0.23051671214188268, 0.6333333333333333, 'Age <= 28.5\n0.492\n149\n[65, 84]\nsobrevivio'),
#  Text(0.1800818553888131, 0.5666666666666667, 'Fare <= 71.4\n0.42\n40\n[12, 28]\nsobrevivio'),
#  Text(0.16234652114597545, 0.5, 'Age <= 24.5\n0.353\n35\n[8, 27]\nsobrevivio'),
#  Text(0.1432469304229195, 0.43333333333333335, 'Age <= 23.5\n0.236\n22\n[3, 19]\nsobrevivio'),
#  Text(0.1377899045020464, 0.36666666666666664, 'SibSp <= 0.5\n0.337\n14\n[3, 11]\nsobrevivio'),
#  Text(0.12687585266030013, 0.3, 'Fare <= 19.023\n0.198\n9\n[1, 8]\nsobrevivio'),
#  Text(0.12141882673942701, 0.23333333333333334, 'Fare <= 14.419\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.11596180081855388, 0.16666666666666666, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.12687585266030013, 0.16666666666666666, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.13233287858117326, 0.23333333333333334, '0.0\n7\n[0, 7]\nsobrevivio'),
#  Text(0.14870395634379263, 0.3, 'Fare <= 32.875\n0.48\n5\n[2, 3]\nsobrevivio'),
#  Text(0.1432469304229195, 0.23333333333333334, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.15416098226466576, 0.23333333333333334, 'Age <= 20.5\n0.444\n3\n[2, 1]\nMurio'),
#  Text(0.14870395634379263, 0.16666666666666666, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.15961800818553887, 0.16666666666666666, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.14870395634379263, 0.36666666666666664, '0.0\n8\n[0, 8]\nsobrevivio'),
#  Text(0.18144611186903137, 0.43333333333333335, 'Pclass <= 1.5\n0.473\n13\n[5, 8]\nsobrevivio'),
#  Text(0.165075034106412, 0.36666666666666664, 'Fare <= 41.3\n0.278\n6\n[1, 5]\nsobrevivio'),
#  Text(0.15961800818553887, 0.3, '0.0\n4\n[0, 4]\nsobrevivio'),
#  Text(0.17053206002728513, 0.3, 'Age <= 26.5\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.165075034106412, 0.23333333333333334, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.17598908594815826, 0.23333333333333334, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.19781718963165076, 0.36666666666666664, 'Age <= 27.5\n0.49\n7\n[4, 3]\nMurio'),
#  Text(0.19236016371077763, 0.3, 'SibSp <= 0.5\n0.32\n5\n[4, 1]\nMurio'),
#  Text(0.1869031377899045, 0.23333333333333334, 'Parch <= 0.5\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.18144611186903137, 0.16666666666666666, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.19236016371077763, 0.16666666666666666, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.19781718963165076, 0.23333333333333334, '0.0\n3\n[3, 0]\nMurio'),
#  Text(0.20327421555252387, 0.3, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.19781718963165076, 0.5, 'Age <= 25.5\n0.32\n5\n[4, 1]\nMurio'),
#  Text(0.19236016371077763, 0.43333333333333335, '0.0\n4\n[4, 0]\nMurio'),
#  Text(0.20327421555252387, 0.43333333333333335, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.28095156889495226, 0.5666666666666667, 'Age <= 29.35\n0.5\n109\n[53, 56]\nsobrevivio'),
#  Text(0.21964529331514324, 0.5, 'Fare <= 26.86\n0.32\n5\n[4, 1]\nMurio'),
#  Text(0.21418826739427013, 0.43333333333333335, 'Fare <= 23.5\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.208731241473397, 0.36666666666666664, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.21964529331514324, 0.36666666666666664, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.22510231923601637, 0.43333333333333335, '0.0\n3\n[3, 0]\nMurio'),
#  Text(0.34225784447476126, 0.5, 'Fare <= 52.277\n0.498\n104\n[49, 55]\nsobrevivio'),
#  Text(0.27933151432469305, 0.43333333333333335, 'Fare <= 23.5\n0.5\n85\n[43, 42]\nMurio'),
#  Text(0.2305593451568895, 0.36666666666666664, 'Fare <= 15.4\n0.397\n11\n[3, 8]\nsobrevivio'),
#  Text(0.21964529331514324, 0.3, 'Fare <= 13.931\n0.444\n3\n[2, 1]\nMurio'),
#  Text(0.21418826739427013, 0.23333333333333334, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.22510231923601637, 0.23333333333333334, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.24147339699863574, 0.3, 'SibSp <= 0.5\n0.219\n8\n[1, 7]\nsobrevivio'),
#  Text(0.23601637107776263, 0.23333333333333334, '0.0\n5\n[0, 5]\nsobrevivio'),
#  Text(0.24693042291950887, 0.23333333333333334, 'Parch <= 1.5\n0.444\n3\n[1, 2]\nsobrevivio'),
#  Text(0.24147339699863574, 0.16666666666666666, 'SibSp <= 2.0\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.23601637107776263, 0.1, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.24693042291950887, 0.1, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.252387448840382, 0.16666666666666666, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.3281036834924966, 0.36666666666666664, 'Age <= 47.5\n0.497\n74\n[40, 34]\nMurio'),
#  Text(0.30013642564802184, 0.3, 'Age <= 36.25\n0.481\n57\n[34, 23]\nMurio'),
#  Text(0.27694406548431105, 0.23333333333333334, 'Age <= 31.5\n0.5\n38\n[19, 19]\nMurio'),
#  Text(0.26330150068212826, 0.16666666666666666, 'Age <= 30.5\n0.463\n22\n[14, 8]\nMurio'),
#  Text(0.2578444747612551, 0.1, 'Fare <= 26.275\n0.494\n18\n[10, 8]\nMurio'),
#  Text(0.252387448840382, 0.03333333333333333, '0.0\n3\n[3, 0]\nMurio'),
#  Text(0.26330150068212826, 0.03333333333333333, '0.498\n15\n[7, 8]\nsobrevivio'),
#  Text(0.26875852660300137, 0.1, '0.0\n4\n[4, 0]\nMurio'),
#  Text(0.29058663028649384, 0.16666666666666666, 'Pclass <= 1.5\n0.43\n16\n[5, 11]\nsobrevivio'),
#  Text(0.27967257844474763, 0.1, 'Fare <= 35.312\n0.245\n7\n[1, 6]\nsobrevivio'),
#  Text(0.2742155525238745, 0.03333333333333333, '0.0\n5\n[0, 5]\nsobrevivio'),
#  Text(0.28512960436562074, 0.03333333333333333, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.3015006821282401, 0.1, 'S <= 0.5\n0.494\n9\n[4, 5]\nsobrevivio'),
#  Text(0.296043656207367, 0.03333333333333333, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.3069577080491132, 0.03333333333333333, '0.469\n8\n[3, 5]\nsobrevivio'),
#  Text(0.32332878581173263, 0.23333333333333334, 'Age <= 45.25\n0.332\n19\n[15, 4]\nMurio'),
#  Text(0.3178717598908595, 0.16666666666666666, 'Age <= 39.5\n0.408\n14\n[10, 4]\nMurio'),
#  Text(0.31241473396998637, 0.1, '0.0\n4\n[4, 0]\nMurio'),
#  Text(0.32332878581173263, 0.1, 'Fare <= 33.25\n0.48\n10\n[6, 4]\nMurio'),
#  Text(0.3178717598908595, 0.03333333333333333, '0.5\n8\n[4, 4]\nMurio'),
#  Text(0.32878581173260574, 0.03333333333333333, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.32878581173260574, 0.16666666666666666, '0.0\n5\n[5, 0]\nMurio'),
#  Text(0.35607094133697137, 0.3, 'Age <= 53.5\n0.457\n17\n[6, 11]\nsobrevivio'),
#  Text(0.3451568894952251, 0.23333333333333334, 'S <= 0.5\n0.18\n10\n[1, 9]\nsobrevivio'),
#  Text(0.339699863574352, 0.16666666666666666, 'Age <= 49.0\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.33424283765347884, 0.1, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.3451568894952251, 0.1, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.3506139154160982, 0.16666666666666666, '0.0\n8\n[0, 8]\nsobrevivio'),
#  Text(0.3669849931787176, 0.23333333333333334, 'Age <= 55.5\n0.408\n7\n[5, 2]\nMurio'),
#  Text(0.3615279672578445, 0.16666666666666666, '0.0\n4\n[4, 0]\nMurio'),
#  Text(0.37244201909959074, 0.16666666666666666, 'Fare <= 28.125\n0.444\n3\n[1, 2]\nsobrevivio'),
#  Text(0.3669849931787176, 0.1, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.37789904502046384, 0.1, 'Age <= 57.0\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.37244201909959074, 0.03333333333333333, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.38335607094133695, 0.03333333333333333, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.4051841746248295, 0.43333333333333335, 'Age <= 49.5\n0.432\n19\n[6, 13]\nsobrevivio'),
#  Text(0.39972714870395637, 0.36666666666666664, 'SibSp <= 1.5\n0.305\n16\n[3, 13]\nsobrevivio'),
#  Text(0.3942701227830832, 0.3, 'Age <= 36.0\n0.231\n15\n[2, 13]\nsobrevivio'),
#  Text(0.3888130968622101, 0.23333333333333334, '0.0\n6\n[0, 6]\nsobrevivio'),
#  Text(0.39972714870395637, 0.23333333333333334, 'Parch <= 0.5\n0.346\n9\n[2, 7]\nsobrevivio'),
#  Text(0.3942701227830832, 0.16666666666666666, 'S <= 0.5\n0.48\n5\n[2, 3]\nsobrevivio'),
#  Text(0.3888130968622101, 0.1, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.39972714870395637, 0.1, 'Fare <= 52.827\n0.444\n3\n[2, 1]\nMurio'),
#  Text(0.3942701227830832, 0.03333333333333333, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.4051841746248295, 0.03333333333333333, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.4051841746248295, 0.16666666666666666, '0.0\n4\n[0, 4]\nsobrevivio'),
#  Text(0.4051841746248295, 0.3, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.4106412005457026, 0.36666666666666664, '0.0\n3\n[3, 0]\nMurio'),
#  Text(0.4638472032742155, 0.6333333333333333, 'Fare <= 211.419\n0.348\n58\n[13, 45]\nsobrevivio'),
#  Text(0.4406548431105048, 0.5666666666666667, 'Age <= 25.5\n0.282\n47\n[8, 39]\nsobrevivio'),
#  Text(0.42155525238744884, 0.5, 'Fare <= 99.99\n0.444\n9\n[3, 6]\nsobrevivio'),
#  Text(0.41609822646657574, 0.43333333333333335, '0.0\n4\n[0, 4]\nsobrevivio'),
#  Text(0.42701227830832195, 0.43333333333333335, 'Parch <= 1.0\n0.48\n5\n[3, 2]\nMurio'),
#  Text(0.42155525238744884, 0.36666666666666664, 'Age <= 20.0\n0.5\n4\n[2, 2]\nMurio'),
#  Text(0.41609822646657574, 0.3, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.42701227830832195, 0.3, 'Fare <= 124.454\n0.444\n3\n[1, 2]\nsobrevivio'),
#  Text(0.42155525238744884, 0.23333333333333334, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.4324693042291951, 0.23333333333333334, 'S <= 0.5\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.42701227830832195, 0.16666666666666666, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.4379263301500682, 0.16666666666666666, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.4324693042291951, 0.36666666666666664, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.4597544338335607, 0.5, 'Age <= 35.5\n0.229\n38\n[5, 33]\nsobrevivio'),
#  Text(0.4542974079126876, 0.43333333333333335, '0.0\n16\n[0, 16]\nsobrevivio'),
#  Text(0.46521145975443384, 0.43333333333333335, 'Q <= 0.5\n0.351\n22\n[5, 17]\nsobrevivio'),
#  Text(0.4597544338335607, 0.36666666666666664, 'Age <= 38.5\n0.308\n21\n[4, 17]\nsobrevivio'),
#  Text(0.4488403819918145, 0.3, 'Parch <= 1.5\n0.5\n4\n[2, 2]\nMurio'),
#  Text(0.4433833560709413, 0.23333333333333334, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.4542974079126876, 0.23333333333333334, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.47066848567530695, 0.3, 'Fare <= 99.963\n0.208\n17\n[2, 15]\nsobrevivio'),
#  Text(0.46521145975443384, 0.23333333333333334, '0.0\n8\n[0, 8]\nsobrevivio'),
#  Text(0.4761255115961801, 0.23333333333333334, 'Fare <= 122.267\n0.346\n9\n[2, 7]\nsobrevivio'),
#  Text(0.47066848567530695, 0.16666666666666666, 'Age <= 44.0\n0.444\n3\n[2, 1]\nMurio'),
#  Text(0.46521145975443384, 0.1, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.4761255115961801, 0.1, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.4815825375170532, 0.16666666666666666, '0.0\n6\n[0, 6]\nsobrevivio'),
#  Text(0.47066848567530695, 0.36666666666666664, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.4870395634379263, 0.5666666666666667, 'Age <= 32.35\n0.496\n11\n[5, 6]\nsobrevivio'),
#  Text(0.4815825375170532, 0.5, 'Fare <= 254.948\n0.408\n7\n[5, 2]\nMurio'),
#  Text(0.4761255115961801, 0.43333333333333335, '0.0\n4\n[4, 0]\nMurio'),
#  Text(0.4870395634379263, 0.43333333333333335, 'Age <= 20.0\n0.444\n3\n[1, 2]\nsobrevivio'),
#  Text(0.4815825375170532, 0.36666666666666664, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.4924965893587995, 0.36666666666666664, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.4924965893587995, 0.5, '0.0\n4\n[0, 4]\nsobrevivio'),
#  Text(0.5034106412005457, 0.7666666666666667, 'Age <= 75.5\n0.278\n12\n[10, 2]\nMurio'),
#  Text(0.4979536152796726, 0.7, 'Fare <= 74.479\n0.165\n11\n[10, 1]\nMurio'),
#  Text(0.4924965893587995, 0.6333333333333333, '0.0\n9\n[9, 0]\nMurio'),
#  Text(0.5034106412005457, 0.6333333333333333, 'Parch <= 2.0\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.4979536152796726, 0.5666666666666667, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.5088676671214188, 0.5666666666666667, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.5088676671214188, 0.7, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.634549795361528, 0.9, 'Age <= 6.5\n0.368\n391\n[296, 95]\nMurio'),
#  Text(0.5361527967257844, 0.8333333333333334, 'SibSp <= 2.5\n0.461\n25\n[9, 16]\nsobrevivio'),
#  Text(0.5252387448840382, 0.7666666666666667, 'Fare <= 10.798\n0.124\n15\n[1, 14]\nsobrevivio'),
#  Text(0.519781718963165, 0.7, 'S <= 0.5\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.514324693042292, 0.6333333333333333, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.5252387448840382, 0.6333333333333333, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.5306957708049114, 0.7, '0.0\n13\n[0, 13]\nsobrevivio'),
#  Text(0.5470668485675307, 0.7666666666666667, 'Age <= 4.5\n0.32\n10\n[8, 2]\nMurio'),
#  Text(0.5416098226466576, 0.7, 'Fare <= 31.331\n0.198\n9\n[8, 1]\nMurio'),
#  Text(0.5361527967257844, 0.6333333333333333, '0.0\n6\n[6, 0]\nMurio'),
#  Text(0.5470668485675307, 0.6333333333333333, 'Age <= 2.0\n0.444\n3\n[2, 1]\nMurio'),
#  Text(0.5416098226466576, 0.5666666666666667, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.5525238744884038, 0.5666666666666667, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.5525238744884038, 0.7, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.7329467939972715, 0.8333333333333334, 'S <= 0.5\n0.339\n366\n[287, 79]\nMurio'),
#  Text(0.5989085948158254, 0.7666666666666667, 'Age <= 29.85\n0.436\n112\n[76, 36]\nMurio'),
#  Text(0.5934515688949522, 0.7, 'Fare <= 7.729\n0.469\n96\n[60, 36]\nMurio'),
#  Text(0.5688949522510232, 0.6333333333333333, 'Age <= 15.0\n0.33\n24\n[19, 5]\nMurio'),
#  Text(0.5634379263301501, 0.5666666666666667, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.5743519781718963, 0.5666666666666667, 'Q <= 0.5\n0.287\n23\n[19, 4]\nMurio'),
#  Text(0.5688949522510232, 0.5, 'Age <= 21.0\n0.36\n17\n[13, 4]\nMurio'),
#  Text(0.557980900409277, 0.43333333333333335, 'Age <= 18.5\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.5525238744884038, 0.36666666666666664, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.5634379263301501, 0.36666666666666664, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.5798090040927695, 0.43333333333333335, 'Age <= 29.1\n0.32\n15\n[12, 3]\nMurio'),
#  Text(0.5743519781718963, 0.36666666666666664, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.5852660300136425, 0.36666666666666664, 'Fare <= 7.227\n0.355\n13\n[10, 3]\nMurio'),
#  Text(0.5798090040927695, 0.3, '0.278\n6\n[5, 1]\nMurio'),
#  Text(0.5907230559345157, 0.3, '0.408\n7\n[5, 2]\nMurio'),
#  Text(0.5798090040927695, 0.5, '0.0\n6\n[6, 0]\nMurio'),
#  Text(0.6180081855388813, 0.6333333333333333, 'Age <= 12.5\n0.49\n72\n[41, 31]\nMurio'),
#  Text(0.6125511596180082, 0.5666666666666667, '0.0\n4\n[4, 0]\nMurio'),
#  Text(0.6234652114597544, 0.5666666666666667, 'Age <= 16.5\n0.496\n68\n[37, 31]\nMurio'),
#  Text(0.607094133697135, 0.5, 'Age <= 14.75\n0.278\n6\n[1, 5]\nsobrevivio'),
#  Text(0.6016371077762619, 0.43333333333333335, 'Fare <= 12.848\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.5961800818553888, 0.36666666666666664, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.607094133697135, 0.36666666666666664, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.6125511596180082, 0.43333333333333335, '0.0\n4\n[0, 4]\nsobrevivio'),
#  Text(0.6398362892223738, 0.5, 'Fare <= 14.852\n0.487\n62\n[36, 26]\nMurio'),
#  Text(0.6234652114597544, 0.43333333333333335, 'Fare <= 7.888\n0.439\n43\n[29, 14]\nMurio'),
#  Text(0.6180081855388813, 0.36666666666666664, 'Fare <= 7.854\n0.495\n31\n[17, 14]\nMurio'),
#  Text(0.6125511596180082, 0.3, 'Age <= 21.5\n0.477\n28\n[17, 11]\nMurio'),
#  Text(0.607094133697135, 0.23333333333333334, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.6180081855388813, 0.23333333333333334, 'Age <= 23.5\n0.488\n26\n[15, 11]\nMurio'),
#  Text(0.6125511596180082, 0.16666666666666666, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.6234652114597544, 0.16666666666666666, 'Age <= 27.0\n0.48\n25\n[15, 10]\nMurio'),
#  Text(0.6180081855388813, 0.1, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.6289222373806276, 0.1, 'Age <= 29.35\n0.486\n24\n[14, 10]\nMurio'),
#  Text(0.6234652114597544, 0.03333333333333333, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.6343792633015006, 0.03333333333333333, '0.476\n23\n[14, 9]\nMurio'),
#  Text(0.6234652114597544, 0.3, '0.0\n3\n[0, 3]\nsobrevivio'),
#  Text(0.6289222373806276, 0.36666666666666664, '0.0\n12\n[12, 0]\nMurio'),
#  Text(0.6562073669849932, 0.43333333333333335, 'Fare <= 23.7\n0.465\n19\n[7, 12]\nsobrevivio'),
#  Text(0.6507503410641201, 0.36666666666666664, 'Age <= 29.35\n0.415\n17\n[5, 12]\nsobrevivio'),
#  Text(0.645293315143247, 0.3, '0.0\n4\n[0, 4]\nsobrevivio'),
#  Text(0.6562073669849932, 0.3, 'Fare <= 22.019\n0.473\n13\n[5, 8]\nsobrevivio'),
#  Text(0.6507503410641201, 0.23333333333333334, 'SibSp <= 0.5\n0.5\n10\n[5, 5]\nMurio'),
#  Text(0.645293315143247, 0.16666666666666666, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.6562073669849932, 0.16666666666666666, 'SibSp <= 1.5\n0.469\n8\n[3, 5]\nsobrevivio'),
#  Text(0.6507503410641201, 0.1, 'Parch <= 0.5\n0.408\n7\n[2, 5]\nsobrevivio'),
#  Text(0.645293315143247, 0.03333333333333333, '0.48\n5\n[2, 3]\nsobrevivio'),
#  Text(0.6562073669849932, 0.03333333333333333, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.6616643929058663, 0.1, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.6616643929058663, 0.23333333333333334, '0.0\n3\n[0, 3]\nsobrevivio'),
#  Text(0.6616643929058663, 0.36666666666666664, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.6043656207366985, 0.7, '0.0\n16\n[16, 0]\nMurio'),
#  Text(0.8669849931787176, 0.7666666666666667, 'Fare <= 51.698\n0.281\n254\n[211, 43]\nMurio'),
#  Text(0.8465211459754434, 0.7, 'Fare <= 20.55\n0.271\n248\n[208, 40]\nMurio'),
#  Text(0.8328785811732605, 0.6333333333333333, 'Parch <= 1.5\n0.294\n218\n[179, 39]\nMurio'),
#  Text(0.8219645293315143, 0.5666666666666667, 'Age <= 11.5\n0.276\n212\n[177, 35]\nMurio'),
#  Text(0.8165075034106412, 0.5, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.8274215552523875, 0.5, 'Age <= 27.5\n0.27\n211\n[177, 34]\nMurio'),
#  Text(0.7503410641200545, 0.43333333333333335, 'Fare <= 7.798\n0.315\n102\n[82, 20]\nMurio'),
#  Text(0.6971350613915416, 0.36666666666666664, 'Age <= 20.75\n0.431\n35\n[24, 11]\nMurio'),
#  Text(0.6780354706684857, 0.3, 'Fare <= 7.573\n0.165\n11\n[10, 1]\nMurio'),
#  Text(0.6725784447476125, 0.23333333333333334, 'Fare <= 7.373\n0.32\n5\n[4, 1]\nMurio'),
#  Text(0.6671214188267395, 0.16666666666666666, '0.0\n4\n[4, 0]\nMurio'),
#  Text(0.6780354706684857, 0.16666666666666666, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.6834924965893588, 0.23333333333333334, '0.0\n6\n[6, 0]\nMurio'),
#  Text(0.7162346521145976, 0.3, 'Fare <= 7.523\n0.486\n24\n[14, 10]\nMurio'),
#  Text(0.694406548431105, 0.23333333333333334, 'Fare <= 3.525\n0.397\n11\n[8, 3]\nMurio'),
#  Text(0.6889495225102319, 0.16666666666666666, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.6998635743519782, 0.16666666666666666, 'Age <= 24.5\n0.32\n10\n[8, 2]\nMurio'),
#  Text(0.694406548431105, 0.1, 'Age <= 23.0\n0.375\n8\n[6, 2]\nMurio'),
#  Text(0.6889495225102319, 0.03333333333333333, '0.278\n6\n[5, 1]\nMurio'),
#  Text(0.6998635743519782, 0.03333333333333333, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.7053206002728513, 0.1, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.73806275579809, 0.23333333333333334, 'Age <= 23.5\n0.497\n13\n[6, 7]\nsobrevivio'),
#  Text(0.7216916780354706, 0.16666666666666666, 'Fare <= 7.763\n0.408\n7\n[2, 5]\nsobrevivio'),
#  Text(0.7162346521145976, 0.1, '0.0\n3\n[0, 3]\nsobrevivio'),
#  Text(0.7271487039563438, 0.1, 'Fare <= 7.785\n0.5\n4\n[2, 2]\nMurio'),
#  Text(0.7216916780354706, 0.03333333333333333, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.732605729877217, 0.03333333333333333, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.7544338335607094, 0.16666666666666666, 'Age <= 26.5\n0.444\n6\n[4, 2]\nMurio'),
#  Text(0.7489768076398363, 0.1, 'SibSp <= 0.5\n0.32\n5\n[4, 1]\nMurio'),
#  Text(0.7435197817189632, 0.03333333333333333, '0.0\n3\n[3, 0]\nMurio'),
#  Text(0.7544338335607094, 0.03333333333333333, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.7598908594815825, 0.1, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.8035470668485676, 0.36666666666666664, 'Age <= 18.5\n0.233\n67\n[58, 9]\nMurio'),
#  Text(0.7871759890859482, 0.3, 'SibSp <= 0.5\n0.391\n15\n[11, 4]\nMurio'),
#  Text(0.781718963165075, 0.23333333333333334, 'Fare <= 9.283\n0.48\n10\n[6, 4]\nMurio'),
#  Text(0.7762619372442019, 0.16666666666666666, 'Fare <= 8.175\n0.375\n8\n[6, 2]\nMurio'),
#  Text(0.7708049113233287, 0.1, 'Age <= 15.0\n0.5\n4\n[2, 2]\nMurio'),
#  Text(0.7653478854024557, 0.03333333333333333, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.7762619372442019, 0.03333333333333333, '0.444\n3\n[1, 2]\nsobrevivio'),
#  Text(0.781718963165075, 0.1, '0.0\n4\n[4, 0]\nMurio'),
#  Text(0.7871759890859482, 0.16666666666666666, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.7926330150068213, 0.23333333333333334, '0.0\n5\n[5, 0]\nMurio'),
#  Text(0.819918144611187, 0.3, 'Age <= 25.5\n0.174\n52\n[47, 5]\nMurio'),
#  Text(0.8035470668485676, 0.23333333333333334, 'SibSp <= 0.5\n0.091\n42\n[40, 2]\nMurio'),
#  Text(0.7980900409276944, 0.16666666666666666, '0.0\n37\n[37, 0]\nMurio'),
#  Text(0.8090040927694406, 0.16666666666666666, 'Age <= 24.5\n0.48\n5\n[3, 2]\nMurio'),
#  Text(0.8035470668485676, 0.1, 'Age <= 22.0\n0.444\n3\n[1, 2]\nsobrevivio'),
#  Text(0.7980900409276944, 0.03333333333333333, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.8090040927694406, 0.03333333333333333, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.8144611186903138, 0.1, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.8362892223738063, 0.23333333333333334, 'SibSp <= 0.5\n0.42\n10\n[7, 3]\nMurio'),
#  Text(0.8308321964529332, 0.16666666666666666, 'Fare <= 7.91\n0.49\n7\n[4, 3]\nMurio'),
#  Text(0.82537517053206, 0.1, 'Fare <= 7.871\n0.32\n5\n[4, 1]\nMurio'),
#  Text(0.819918144611187, 0.03333333333333333, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.8308321964529332, 0.03333333333333333, '0.0\n4\n[4, 0]\nMurio'),
#  Text(0.8362892223738063, 0.1, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.8417462482946794, 0.16666666666666666, '0.0\n3\n[3, 0]\nMurio'),
#  Text(0.9045020463847203, 0.43333333333333335, 'Fare <= 7.91\n0.224\n109\n[95, 14]\nMurio'),
#  Text(0.8744884038199181, 0.36666666666666664, 'Age <= 32.5\n0.083\n46\n[44, 2]\nMurio'),
#  Text(0.869031377899045, 0.3, 'Age <= 31.5\n0.159\n23\n[21, 2]\nMurio'),
#  Text(0.8581173260572987, 0.23333333333333334, 'Fare <= 7.785\n0.091\n21\n[20, 1]\nMurio'),
#  Text(0.8526603001364257, 0.16666666666666666, 'Fare <= 7.663\n0.198\n9\n[8, 1]\nMurio'),
#  Text(0.8472032742155525, 0.1, '0.0\n6\n[6, 0]\nMurio'),
#  Text(0.8581173260572987, 0.1, 'Age <= 29.35\n0.444\n3\n[2, 1]\nMurio'),
#  Text(0.8526603001364257, 0.03333333333333333, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.8635743519781719, 0.03333333333333333, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.8635743519781719, 0.16666666666666666, '0.0\n12\n[12, 0]\nMurio'),
#  Text(0.8799454297407913, 0.23333333333333334, 'Fare <= 7.875\n0.5\n2\n[1, 1]\nMurio'),
#  Text(0.8744884038199181, 0.16666666666666666, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.8854024556616644, 0.16666666666666666, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.8799454297407913, 0.3, '0.0\n23\n[23, 0]\nMurio'),
#  Text(0.9345156889495225, 0.36666666666666664, 'Fare <= 7.988\n0.308\n63\n[51, 12]\nMurio'),
#  Text(0.9072305593451568, 0.3, 'SibSp <= 1.0\n0.49\n7\n[3, 4]\nsobrevivio'),
#  Text(0.9017735334242838, 0.23333333333333334, 'Age <= 31.5\n0.444\n6\n[2, 4]\nsobrevivio'),
#  Text(0.8963165075034106, 0.16666666666666666, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.9072305593451568, 0.16666666666666666, 'Age <= 41.5\n0.48\n5\n[2, 3]\nsobrevivio'),
#  Text(0.9017735334242838, 0.1, 'Age <= 35.5\n0.5\n4\n[2, 2]\nMurio'),
#  Text(0.8963165075034106, 0.03333333333333333, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.9072305593451568, 0.03333333333333333, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.91268758526603, 0.1, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.91268758526603, 0.23333333333333334, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.9618008185538881, 0.3, 'Age <= 59.25\n0.245\n56\n[48, 8]\nMurio'),
#  Text(0.956343792633015, 0.23333333333333334, 'Fare <= 15.975\n0.222\n55\n[48, 7]\nMurio'),
#  Text(0.9345156889495225, 0.16666666666666666, 'Age <= 44.5\n0.159\n46\n[42, 4]\nMurio'),
#  Text(0.9236016371077762, 0.1, 'Fare <= 8.081\n0.133\n42\n[39, 3]\nMurio'),
#  Text(0.9181446111869032, 0.03333333333333333, '0.0\n21\n[21, 0]\nMurio'),
#  Text(0.9290586630286494, 0.03333333333333333, '0.245\n21\n[18, 3]\nMurio'),
#  Text(0.9454297407912687, 0.1, 'Age <= 46.0\n0.375\n4\n[3, 1]\nMurio'),
#  Text(0.9399727148703957, 0.03333333333333333, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.9508867667121419, 0.03333333333333333, '0.0\n3\n[3, 0]\nMurio'),
#  Text(0.9781718963165075, 0.16666666666666666, 'Age <= 34.0\n0.444\n9\n[6, 3]\nMurio'),
#  Text(0.9672578444747613, 0.1, 'Fare <= 17.05\n0.278\n6\n[5, 1]\nMurio'),
#  Text(0.9618008185538881, 0.03333333333333333, '0.444\n3\n[2, 1]\nMurio'),
#  Text(0.9727148703956344, 0.03333333333333333, '0.0\n3\n[3, 0]\nMurio'),
#  Text(0.9890859481582538, 0.1, 'SibSp <= 0.5\n0.444\n3\n[1, 2]\nsobrevivio'),
#  Text(0.9836289222373806, 0.03333333333333333, '0.0\n1\n[1, 0]\nMurio'),
#  Text(0.9945429740791268, 0.03333333333333333, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.9672578444747613, 0.23333333333333334, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.8437926330150068, 0.5666666666666667, 'Age <= 33.75\n0.444\n6\n[2, 4]\nsobrevivio'),
#  Text(0.8383356070941337, 0.5, '0.0\n4\n[0, 4]\nsobrevivio'),
#  Text(0.8492496589358799, 0.5, '0.0\n2\n[2, 0]\nMurio'),
#  Text(0.8601637107776262, 0.6333333333333333, 'Parch <= 4.5\n0.064\n30\n[29, 1]\nMurio'),
#  Text(0.854706684856753, 0.5666666666666667, '0.0\n25\n[25, 0]\nMurio'),
#  Text(0.8656207366984994, 0.5666666666666667, 'Age <= 38.5\n0.32\n5\n[4, 1]\nMurio'),
#  Text(0.8601637107776262, 0.5, '0.0\n1\n[0, 1]\nsobrevivio'),
#  Text(0.8710777626193724, 0.5, '0.0\n4\n[4, 0]\nMurio'),
#  Text(0.8874488403819918, 0.7, 'Parch <= 1.0\n0.5\n6\n[3, 3]\nMurio'),
#  Text(0.8819918144611187, 0.6333333333333333, 'Age <= 30.85\n0.375\n4\n[1, 3]\nsobrevivio'),
#  Text(0.8765347885402456, 0.5666666666666667, '0.5\n2\n[1, 1]\nMurio'),
#  Text(0.8874488403819918, 0.5666666666666667, '0.0\n2\n[0, 2]\nsobrevivio'),
#  Text(0.892905866302865, 0.6333333333333333, '0.0\n2\n[2, 0]\nMurio')]
