# %%
#Tensor flow

# %%
import pandas as pd 

datos = pd.read_csv('Celsius.csv')

# %%
datos.head()
# Out:
#    Celsius  Fahrenheit
# 0      -40       -40.0
# 1      -10        14.0
# 2        0        32.0
# 3        8        46.4
# 4       15        59.0

# %%
datos["Celsius"].values
# Out:
# array([-40, -10,   0,   8,  15,  22,  38], dtype=int64)

# %%
x  = datos["Celsius"].values
y  = datos["Fahrenheit"].values

# %%
import tensorflow as tf 

modelo = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)), #La entrada, los celsius: 1 solo dato
    tf.keras.layers.Dense(units=1), #La salida, los grafos farhenheit 
])

modelo.compile(
    optimizer = tf.keras.optimizers.Adam(.1),
    loss = 'mean_squared_error'
)
# Out:
# WARNING:tensorflow:From C:\Users\eobga\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\eobga\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
#Entrenamiento
entrenamiento = modelo.fit(x,y, epochs=1000) #epochs marca las vueltas que le daremos al set de datos
# Out:
# Epoch 1/1000
# WARNING:tensorflow:From C:\Users\eobga\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1/1 [==============================] - 1s 1s/step - loss: 5627.0659
# Epoch 2/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 5301.5083
# Epoch 3/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4987.6812
# Epoch 4/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4685.7720
# Epoch 5/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4395.9492
# Epoch 6/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 4118.3540
# Epoch 7/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 3853.0969
# Epoch 8/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 3600.2649
# Epoch 9/1000
# ...

# %%
#Ver datos graficamente
import matplotlib.pyplot as plt

plt.xlabel("# Epoca")
plt.ylabel("Magnitud de la perdida")
plt.plot(entrenamiento.history["loss"]) #Hacer una grafica de la historia del loss

# %%
#Hacer la prediccion
c = 1230
prediccion = modelo.predict([c])
print(f"prediccion: {c} celsius son {prediccion[0]} fahrenheit")
# Out:
# 1/1 [==============================] - 0s 84ms/step
# prediccion: 1230 celsius son [2246.4058] fahrenheit

# %%
print(modelo.layers[0].get_weights())
# Out:
# [array([[1.8003641]], dtype=float32), array([31.957752], dtype=float32)]
